# %% [markdown]
# # Time Series Analysis
# This project is an analysis project where we have collected and analyzed stock data of Apple Inc. since February 2013 to February 2018.
# Further the data is visualized in the form of graphs and charts and the explanation is being provided for more reference.

# %%
import pandas as pd   #Import of library to load and work on the dataset

# %%
df=pd.read_csv(r"D:\Zidio\AAPL_5yr_stock_data.csv")    #Loading of the dataset 
df
# Out:
#             date      open      high       low     close     volume  Name
# 0     2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 1     2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2     2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 3     2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 4     2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...          ...       ...       ...       ...       ...        ...   ...
# 1254  2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 1255  2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 1256  2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 1257  2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 1258  2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 7 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of             date      open      high       low     close     volume  Name
# 0     2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 1     2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2     2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 3     2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 4     2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...          ...       ...       ...       ...       ...        ...   ...
# 1254  2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 1255  2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 1256  2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 1257  2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 1258  2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 7 columns]>

# %% [markdown]
# Complete loading and information of the data is complete. The library imported to load and collect information of data is pandas.

# %%
#Cleaning and wrangling of data 

rows=df.shape[0]
columns=df.shape[1]
print("Number of rows=", rows)
print("Number of columns=", columns)
df.replace("NaN", pd.NA, inplace=True)
print(df.columns.tolist())
missing=df.isnull().sum()
print("")
print("Total missing values in each column in the given dataset")
print(missing)
# Out:
# Number of rows= 1259
# Number of columns= 10
# ['date', 'open', 'high', 'low', 'close', 'volume', 'Name', 'day_of_week', 'year', 'quarter']
#
# Total missing values in each column in the given dataset
# date           0
# open           0
# high           0
# low            0
# close          0
# volume         0
# Name           0
# day_of_week    0
# year           0
# quarter        0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df = df.drop_duplicates()
df.columns = [col.strip().lower().replace(" ", "_") for col in df.columns]
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   datetime64[ns]
#  1   open    1259 non-null   float64
#  2   high    1259 non-null   float64
#  3   low     1259 non-null   float64
#  4   close   1259 non-null   float64
#  5   volume  1259 non-null   int64
#  6   name    1259 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 69.0+ KB
# None

# %%
#Visualisation of the dataset

print(df.describe())

#Two main libraries, matplotlib and seaborn is used for the visualization in order to use graphs and charts

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 4))
plt.plot(df['date'], df['close'])
plt.title('Close Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
sns.histplot(df['volume'], bins=50, kde=True)
plt.title('Volume Distribution')
plt.show()

sns.boxplot(x=df['close'])
plt.title('Close Price Outliers')
plt.show()


plt.figure(figsize=(8, 6))
sns.heatmap(df[['open', 'high', 'low', 'close', 'volume']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#                                 date         open         high          low  \
# count                           1259  1259.000000  1259.000000  1259.000000
# mean   2015-08-09 05:44:16.393963264   109.055429   109.951118   108.141589
# min              2013-02-08 00:00:00    55.424200    57.085700    55.014200
# 25%              2014-05-10 12:00:00    84.647800    85.334950    84.250650
# 50%              2015-08-10 00:00:00   108.970000   110.030000   108.050000
# 75%              2016-11-05 12:00:00   127.335000   128.100000   126.290000
# max              2018-02-07 00:00:00   179.370000   180.100000   178.250000
# std                              NaN    30.549220    30.686186    30.376224
#
#              close        volume         year
# count  1259.000000  1.259000e+03  1259.000000
# mean    109.066698  5.404790e+07  2015.101668
# min      55.789900  1.147592e+07  2013.000000
# 25%      84.830650  2.969438e+07  2014.000000
# 50%     109.010000  4.566893e+07  2015.000000
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('AAPL_5yr_stock_data.csv')
df['date'] = pd.to_datetime(df['date'], errors='coerce')
numeric_columns = ['open', 'close']
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df = df.dropna(subset=['open', 'close'])
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='open', y='close', alpha=0.6, color='dodgerblue')
plt.title('Scatter Plot: Open vs Close Price')
plt.xlabel('Open Price')
plt.ylabel('Close Price')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('AAPL_5yr_stock_data.csv')


df['close'] = pd.to_numeric(df['close'], errors='coerce')
df['volume'] = pd.to_numeric(df['volume'], errors='coerce')

df = df.dropna(subset=['close', 'volume'])

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=df['close'], color='skyblue')
plt.title('Boxplot of Close Prices')
plt.xlabel('Close Price')
plt.subplot(1, 2, 2)
sns.boxplot(x=df['volume'], color='salmon')
plt.title('Boxplot of Trading Volume')
plt.xlabel('Volume')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('AAPL_5yr_stock_data.csv')
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df['day_of_week'] = df['date'].dt.day_name()
df['volume'] = pd.to_numeric(df['volume'], errors='coerce')
df = df.dropna(subset=['day_of_week', 'volume'])
plt.figure(figsize=(10, 6))
sns.boxplot(x='day_of_week', y='volume', data=df, palette='Set3')
plt.title('Boxplot of Trading Volume by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Trading Volume')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\abhyu\AppData\Local\Temp\ipykernel_22112\825417120.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day_of_week', y='volume', data=df, palette='Set3')

# %%
df['year'] = df['date'].dt.year
plt.figure(figsize=(10, 6))
sns.boxplot(x='year', y='close', data=df, palette='Blues')
plt.title('Boxplot of Close Prices by Year')
plt.xlabel('Year')
plt.ylabel('Close Price')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\abhyu\AppData\Local\Temp\ipykernel_22112\1283128655.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='year', y='close', data=df, palette='Blues')

# %%
df['quarter'] = df['date'].dt.to_period('Q').astype(str)
plt.figure(figsize=(12, 6))
sns.boxplot(x='quarter', y='close', data=df, palette='PuBuGn')
plt.title('Boxplot of Close Prices by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\abhyu\AppData\Local\Temp\ipykernel_22112\4098680242.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quarter', y='close', data=df, palette='PuBuGn')

# %% [markdown]
# # Description of each visualized chart
#
# 1)The scatter plot of Open vs Close prices reveals a strong positive correlation, suggesting that Apple's daily stock prices are highly consistent. Most points lie close to the diagonal, indicating that the opening and closing prices are usually similar, with minimal volatility. A few noticeable outliers suggest occasional intraday price surges or drops, likely tied to external market events. The overall price range also illustrates Apple's significant growth during the analyzed period.
#
# 2)The boxplot of closing prices shows that Apple’s stock remained relatively stable over the 5-year period, with a tight interquartile range and few significant outliers. This indicates consistent investor confidence. The trading volume boxplot reveals much greater variability, with numerous high-volume outliers, likely triggered by major events or announcements. The comparison between the two plots highlights that while price remained steady, trading activity was more sensitive to market conditions.
#
#
# 3)The boxplot of trading volume by day of the week reveals clear patterns in investor behavior. Trading activity tends to be more intense mid-week (especially on Wednesdays and Thursdays), while Mondays and Fridays see comparatively lower volumes. This suggests that investors may be more cautious at the start and end of the week, and prefer executing trades when markets are more stable and responsive. Notably, outliers across all days indicate occasional volume surges, typically driven by company or market-wide announcements.
#
#
# 4)The boxplot showing Apple’s closing prices by year reveals a clear upward trajectory in the stock's value over the five-year period. Median prices increased consistently, indicating strong long-term performance. Some years displayed a wider spread, reflecting higher price volatility—possibly due to market conditions or company announcements. Outliers highlight significant price jumps or drops that deviate from normal behavior, which could be linked to product releases or investor sentiment. Overall, the chart supports the narrative of Apple as a steadily growing and actively traded stock.
#
#
# 5)The boxplot of Apple’s closing stock prices by quarter reveals key short-term trends and potential seasonal patterns. Certain quarters consistently exhibit higher median prices, likely driven by events such as product launches and year-end sales (e.g., Q4). Periods of greater interquartile range reflect heightened trading activity or market uncertainty. Outliers highlight days of significant deviation from typical price behavior, often aligned with company announcements or economic shifts. This quarterly perspective enables a more detailed understanding of price behavior and can assist in short-term forecasting and strategy development.

# %% [markdown]
# # Conclusion
# The dataset is being properly cleaned and visualized the all the above insights are being successfully concluded.
